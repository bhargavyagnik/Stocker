# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
rel = yf.Ticker("RELIANCE.NS")

# %%
rel.info
# Out:
# {'industry': 'Oil & Gas Refining & Marketing',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 195618,
#  'companyOfficers': [],
#  'maxAge': 1,
#  'previousClose': 2119.85,
#  'regularMarketOpen': 2134.8,
#  'twoHundredDayAverage': 1500.7246,
#  'trailingAnnualDividendYield': 0.0030662545,
#  'payoutRatio': 0.1943,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 2160,
#  'navPrice': None,
#  'averageDailyVolume10Day': 24811217,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 2119.85,
#  'fiftyDayAverage': 1927.4042,
#  'trailingAnnualDividendRate': 6.5,
#  'open': 2134.8,
#  'toCurrency': None,
#  'averageVolume10days': 24811217,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 6.5,
#  'exDividendDate': 1593648000,
#  'beta': 1.112174,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 2100.35,
#  'priceHint': 2,
#  'currency': 'INR',
#  'trailingPE': 31.693554,
#  'regularMarketVolume': 21605154,
# ...

# %%
red_hs=rel.history(period="max")

# %%
red_hs['Low'].plot()

# %%
rel.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1996-05-24    6.00000           0.0
# 1997-05-16    6.50000           0.0
# 1997-10-27    0.00000           2.0
# 1998-05-06    3.50000           0.0
# 1999-05-07    3.75000           0.0
# 2000-04-06    4.00000           0.0
# 2001-04-26    4.25000           0.0
# 2002-10-23    4.75000           0.0
# 2003-05-23    5.00000           0.0
# 2004-05-20    5.25000           0.0
# 2005-05-12    7.50000           0.0
# 2006-06-01   10.00000           0.0
# 2007-03-21   11.00000           0.0
# 2008-05-08   13.00000           0.0
# 2009-10-16   13.00000           0.0
# 2009-11-26    0.00000           2.0
# 2010-05-10    7.00000           0.0
# 2011-05-05    8.00000           0.0
# 2012-05-31    8.50000           0.0
# 2013-05-10    9.00000           0.0
# 2014-05-16    9.50000           0.0
# 2015-05-08   10.00000           0.0
# 2016-03-17   10.50000           0.0
# 2017-07-13    5.44836           0.0
# 2017-09-07    0.00000           2.0
# ...

# %%
rel.major_holders
# Out:
#         0                                      1
# 0  42.17%        % of Shares Held by All Insider
# 1  28.07%       % of Shares Held by Institutions
# 2  48.53%        % of Float Held by Institutions
# 3     318  Number of Institutions Holding Shares

# %%
rel
# Out:
# yfinance.Ticker object <RELIANCE.NS>

# %%
data = yf.download("RELIANCE.NS TSLA", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
#              Adj Close                   Close                    High  \
#            RELIANCE.NS        TSLA RELIANCE.NS        TSLA RELIANCE.NS
# Date
# 2017-01-02  530.454773         NaN  542.549988         NaN  545.000000
# 2017-01-03  532.556885  216.990005  544.700012  216.990005  548.500000
# 2017-01-04  521.679932  226.990005  533.575012  226.990005  546.500000
# 2017-01-05  526.690674  226.750000  538.700012  226.750000  539.950012
# 2017-01-06  525.492920  229.009995  537.474976  229.009995  542.500000
# ...                ...         ...         ...         ...         ...
# 2017-04-24  692.900757  308.029999  708.700012  308.029999  717.500000
# 2017-04-25  700.429077  313.790009  716.400024  313.790009  733.875000
# 2017-04-26  692.436340  310.170013  708.224976  310.170013  720.025024
# 2017-04-27  689.038818  308.630005  704.750000  308.630005  712.075012
# 2017-04-28  682.048157  314.070007  697.599976  314.070007  710.150024
#
# ...
